# %%
# 미션 진행을 위해 필요한 라이브러리 로드합니다.
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# 미션 수행을 위해 데이터를 로드합니다.
df = pd.read_csv("https://bit.ly/telco-csv", index_col="customerID")
df.shape
# Out:
# (7043, 20)

# %%
# 데이터 프레임에서 가장 앞에 있는 N개의 행을 출력합니다.
df.head(2)
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
#
#            DeviceProtection TechSupport StreamingTV StreamingMovies  \
# customerID
# 7590-VHVEG               No          No          No              No
# 5575-GNVDE              Yes          No          No              No
#
#                   Contract PaperlessBilling     PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG  Month-to-month              Yes  Electronic check           29.85
# 5575-GNVDE        One year               No      Mailed check           56.95
#
#            TotalCharges Churn
# customerID
# 7590-VHVEG        29.85    No
# 5575-GNVDE       1889.5    No

# %%
# 데이터 집합과 각 열들의 자료형을 확인합니다.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7043 non-null   object
#  19  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
# df.isnull().sum()는 컬럼별로 결측치의 합계를 구합니다.
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# df.isnull().sum().sum() 전체 결측치의 합계를 구합니다.
df.isnull().sum().sum()
# Out:
# 0

# %%
# 숫자형태로 된 문자열을 숫자형으로 바꿔줍니다.
# 공백문자 등의 결측치가 들어있다면 .str.strip()을 통해 공백문자를 제거합니다.
# .replace("", np.nan) 는 공백문자를 결측치로 변경해 줍니다.
# .astype(float) 으로 수치형태로 변환해 줍니다.
df["TotalCharges"] = df["TotalCharges"].str.strip().replace("", np.nan).astype(float)

# %%
# 바이너리 변수 인코딩을 위해 범주 값이 2개로 되어 있어 이진값으로 인코딩이 가능한 변수를 찾습니다.
nuniq = df.nunique()
bi_cols = nuniq[nuniq == 2].index
bi_cols
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
#        'PaperlessBilling', 'Churn'],
#       dtype='object')

# %%
df[bi_cols]
# Out:
#             gender  SeniorCitizen Partner Dependents PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No           No
# 5575-GNVDE    Male              0      No         No          Yes
# 3668-QPYBK    Male              0      No         No          Yes
# 7795-CFOCW    Male              0      No         No           No
# 9237-HQITU  Female              0      No         No          Yes
# ...            ...            ...     ...        ...          ...
# 6840-RESVB    Male              0     Yes        Yes          Yes
# 2234-XADUH  Female              0     Yes        Yes          Yes
# 4801-JZAZL  Female              0     Yes        Yes           No
# 8361-LTMKD    Male              1     Yes         No          Yes
# 3186-AJIEK    Male              0      No         No          Yes
#
#            PaperlessBilling Churn
# customerID
# 7590-VHVEG              Yes    No
# 5575-GNVDE               No    No
# 3668-QPYBK              Yes   Yes
# 7795-CFOCW               No    No
# 9237-HQITU              Yes   Yes
# ...                     ...   ...
# 6840-RESVB              Yes    No
# 2234-XADUH              Yes    No
# 4801-JZAZL              Yes    No
# 8361-LTMKD              Yes   Yes
# 3186-AJIEK              Yes    No
#
# [7043 rows x 7 columns]

# %%
# 바이너리 변수에 대한 인코딩
df["gender_encode"] = (df["gender"] == "Male").astype(int)
df["Partner_encode"] = (df["Partner"] == "Yes").astype(int)
df["Dependents_encode"] = (df["Dependents"] == "Yes").astype(int)
df["PhoneService_encode"] = (df["PhoneService"] == "Yes").astype(int)
df["PaperlessBilling_encode"] = (df["PaperlessBilling"] == "Yes").astype(int)
df
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
# ...            ...            ...     ...        ...     ...          ...
# 6840-RESVB    Male              0     Yes        Yes      24          Yes
# 2234-XADUH  Female              0     Yes        Yes      72          Yes
# 4801-JZAZL  Female              0     Yes        Yes      11           No
# 8361-LTMKD    Male              1     Yes         No       4          Yes
# 3186-AJIEK    Male              0      No         No      66          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# customerID                                                                ...
# 7590-VHVEG  No phone service             DSL             No          Yes  ...
# 5575-GNVDE                No             DSL            Yes           No  ...
# 3668-QPYBK                No             DSL            Yes          Yes  ...
# 7795-CFOCW  No phone service             DSL            Yes           No  ...
# 9237-HQITU                No     Fiber optic             No           No  ...
# ...                      ...             ...            ...          ...  ...
# 6840-RESVB               Yes             DSL            Yes           No  ...
# 2234-XADUH               Yes     Fiber optic             No          Yes  ...
# 4801-JZAZL  No phone service             DSL            Yes           No  ...
# 8361-LTMKD               Yes     Fiber optic             No           No  ...
# 3186-AJIEK                No     Fiber optic            Yes           No  ...
#
#            PaperlessBilling              PaymentMethod MonthlyCharges  \
# customerID
# 7590-VHVEG              Yes           Electronic check          29.85
# 5575-GNVDE               No               Mailed check          56.95
# 3668-QPYBK              Yes               Mailed check          53.85
# 7795-CFOCW               No  Bank transfer (automatic)          42.30
# 9237-HQITU              Yes           Electronic check          70.70
# ...                     ...                        ...            ...
# 6840-RESVB              Yes               Mailed check          84.80
# 2234-XADUH              Yes    Credit card (automatic)         103.20
# 4801-JZAZL              Yes           Electronic check          29.60
# 8361-LTMKD              Yes               Mailed check          74.40
# 3186-AJIEK              Yes  Bank transfer (automatic)         105.65
#
#            TotalCharges Churn gender_encode Partner_encode  Dependents_encode  \
# customerID
# 7590-VHVEG        29.85    No             0              1                  0
# 5575-GNVDE      1889.50    No             1              0                  0
# 3668-QPYBK       108.15   Yes             1              0                  0
# 7795-CFOCW      1840.75    No             1              0                  0
# 9237-HQITU       151.65   Yes             0              0                  0
# ...                 ...   ...           ...            ...                ...
# 6840-RESVB      1990.50    No             1              1                  1
# 2234-XADUH      7362.90    No             0              1                  1
# 4801-JZAZL       346.45    No             0              1                  1
# 8361-LTMKD       306.60   Yes             1              1                  0
# 3186-AJIEK      6844.50    No             1              0                  0
#
#             PhoneService_encode PaperlessBilling_encode
# customerID
# 7590-VHVEG                    0                       1
# 5575-GNVDE                    1                       0
# 3668-QPYBK                    1                       1
# 7795-CFOCW                    0                       0
# 9237-HQITU                    1                       1
# ...                         ...                     ...
# 6840-RESVB                    1                       1
# 2234-XADUH                    1                       1
# 4801-JZAZL                    0                       1
# 8361-LTMKD                    1                       1
# 3186-AJIEK                    1                       1
#
# [7043 rows x 25 columns]

# %%
# 정답의 빈도수 확인
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# value_counts(1) => normalize=True 와 같습니다.
df["Churn"].value_counts(1)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
sns.countplot(data=df, x="Churn")
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
# 학습, 예측에 사용할 컬럼에 이름 지정합니다.
# 범주형 데이터(object, category)는 전처리가 따로 필요합니다.
# 간단하게 모델을 만들어보기 위해 수치 데이터만 사용합니다.
feature_names = df.select_dtypes(include="number").columns
feature_names
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges',
#        'gender_encode', 'Partner_encode', 'Dependents_encode',
#        'PhoneService_encode', 'PaperlessBilling_encode'],
#       dtype='object')

# %%
# label_name 이라는 변수에 예측할 컬럼(Churn)의 이름을 담습니다.
label_name = "Churn"
label_name
# Out:
# 'Churn'

# %%
# X, y를 만들어 줍니다.
# 물음표를 채워 독립변수(X)와 종속변수(y)를 나눠주세요.
# scikit-learn에서 데이터는 대문자 X(2차원,행렬)로 표시하고 정답은 소문자 y(1차원,벡터)로 표기합니다.
X = df[feature_names]
y = df[label_name]
display(X.head(2))
display(y.head(2))
X.shape, y.shape
# Out:
#             SeniorCitizen  tenure  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG              0       1           29.85         29.85
# 5575-GNVDE              0      34           56.95       1889.50
#
#             gender_encode  Partner_encode  Dependents_encode  \
# customerID
# 7590-VHVEG              0               1                  0
# 5575-GNVDE              1               0                  0
#
#             PhoneService_encode  PaperlessBilling_encode
# customerID
# 7590-VHVEG                    0                        1
# 5575-GNVDE                    1                        0
# customerID
# 7590-VHVEG    No
# 5575-GNVDE    No
# Name: Churn, dtype: object
# ((7043, 9), (7043,))

# %%
# 데이터의 행과 열의 개수를 확인합니다.
df.shape
# Out:
# (7043, 25)

# %%
# train 과 test 로 나누기 위해 데이터를 기준을 정합니다.
split_count = int(df.shape[0] * 0.8)
split_count
# Out:
# 5634

# %%
# 데이터의 80%을 나눌 기준 인덱스(split_count)로 문제 데이터(X)를 train, test로 나눕니다.
# 데이터의 80%을 나눌 기준 인덱스(split_count)로 정답 데이터(y)를 train, test로 나눕니다.
X_train = X[:split_count]
y_train = y[:split_count]

X_test = X[:split_count]
y_test = y[:split_count]

print("* 데이터가 잘 나뉘었는지 shape 값을 통해 확인해 보세요.")

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# * 데이터가 잘 나뉘었는지 shape 값을 통해 확인해 보세요.
# ((5634, 9), (5634, 9), (5634,), (5634,))

# %%
# 사이킷런(sklearn)에서 의사 결정 트리 분류모델(DecisionTreeClassifier)을 로드합니다.
# 위 설명에서 제시한 주요 파라미터의 설정을 변경해서 모델을 만들어 주세요.
# 기본값으로 모델을 만들어도 되며 여러 파라미터를 변경하는 방법으로 만들어도 됩니다.

from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
# 데이터를 머신러닝 모델로 학습(fit)합니다.
# 기출문제 X_train 와 기출문제의 정답 y_train 을 넣고 학습을 합니다.
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# 데이터를 머신러닝 모델로 예측(predict)합니다.
y_predict = model.predict(X_test)
y_predict[:5]
# Out:
# array(['Yes', 'No', 'No', 'No', 'Yes'], dtype=object)

# %%
# plot_tree 를 통해 tree 를 시각화 합니다.
# 시각화 할 때만 max_depth를 제한한것이고 실제 모델에서는 다른 값을 사용하게 됩니다.
# 위 예시 이미지를 참고합니다.
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 10))
# 여기에 구현해 주세요.
plot_tree(model, feature_names=feature_names, filled=True, fontsize=10)
# Out:
# [Text(0.38292630798163024, 0.9928571428571429, 'tenure <= 16.5\ngini = 0.389\nsamples = 5634\nvalue = [4146, 1488]'),
#  Text(0.1411455589939426, 0.9785714285714285, 'MonthlyCharges <= 69.225\ngini = 0.495\nsamples = 2048\nvalue = [1122, 926]'),
#  Text(0.06763563339478536, 0.9642857142857143, 'tenure <= 3.5\ngini = 0.418\nsamples = 1142\nvalue = [805, 337]'),
#  Text(0.04065709770871741, 0.95, 'MonthlyCharges <= 20.875\ngini = 0.489\nsamples = 502\nvalue = [288, 214]'),
#  Text(0.021595996839610217, 0.9357142857142857, 'TotalCharges <= 20.275\ngini = 0.387\nsamples = 187\nvalue = [138, 49]'),
#  Text(0.014748485646563076, 0.9214285714285714, 'TotalCharges <= 19.275\ngini = 0.469\nsamples = 96\nvalue = [60, 36]'),
#  Text(0.012641559125625495, 0.9071428571428571, 'gender_encode <= 0.5\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.011588095865156703, 0.8928571428571429, 'TotalCharges <= 19.05\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.010534632604687911, 0.8785714285714286, 'gini = 0.5\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.012641559125625495, 0.8785714285714286, 'gini = 0.0\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.013695022386094284, 0.8928571428571429, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.01685541216750066, 0.9071428571428571, 'TotalCharges <= 20.225\ngini = 0.489\nsamples = 82\nvalue = [47, 35]'),
#  Text(0.015801948907031866, 0.8928571428571429, 'SeniorCitizen <= 0.5\ngini = 0.491\nsamples = 77\nvalue = [44, 33]'),
#  Text(0.014748485646563076, 0.8785714285714286, 'MonthlyCharges <= 20.075\ngini = 0.49\nsamples = 75\nvalue = [44, 31]'),
#  Text(0.012641559125625495, 0.8642857142857143, 'MonthlyCharges <= 20.025\ngini = 0.458\nsamples = 58\nvalue = [37, 21]'),
#  Text(0.011588095865156703, 0.85, 'MonthlyCharges <= 19.925\ngini = 0.465\nsamples = 53\nvalue = [33, 20]'),
#  Text(0.010534632604687911, 0.8357142857142857, 'Partner_encode <= 0.5\ngini = 0.473\nsamples = 48\nvalue = [30, 18]'),
#  Text(0.00948116934421912, 0.8214285714285714, 'Dependents_encode <= 0.5\ngini = 0.48\nsamples = 41\nvalue = [25, 16]'),
#  Text(0.00842770608375033, 0.8071428571428572, 'TotalCharges <= 19.875\ngini = 0.476\nsamples = 38\nvalue = [24, 14]'),
#  Text(0.007374242823281538, 0.7928571428571428, 'TotalCharges <= 19.775\ngini = 0.465\nsamples = 34\nvalue = [22, 12]'),
#  Text(0.006320779562812747, 0.7785714285714286, 'MonthlyCharges <= 19.7\ngini = 0.457\nsamples = 30\nvalue = [20, 10]'),
#  Text(0.005267316302343956, 0.7642857142857142, 'MonthlyCharges <= 19.625\ngini = 0.466\nsamples = 23\nvalue = [14, 9]'),
#  Text(0.004213853041875165, 0.75, 'PaperlessBilling_encode <= 0.5\ngini = 0.463\nsamples = 18\nvalue = [11, 7]'),
#  Text(0.0031603897814063736, 0.7357142857142858, 'gender_encode <= 0.5\ngini = 0.498\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.0021069265209375824, 0.7214285714285714, 'MonthlyCharges <= 19.525\ngini = 0.42\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.0010534632604687912, 0.7071428571428572, 'gini = 0.0\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0031603897814063736, 0.7071428571428572, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.004213853041875165, 0.7214285714285714, 'gini = 0.0\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.005267316302343956, 0.7357142857142858, 'gini = 0.0\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.006320779562812747, 0.75, 'gini = 0.0\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.007374242823281538, 0.7642857142857142, 'gini = 0.0\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.00842770608375033, 0.7785714285714286, 'gini = nan\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.00948116934421912, 0.7928571428571428, 'gini = nan\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.010534632604687911, 0.8071428571428572, 'gini = nan\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.011588095865156703, 0.8214285714285714, 'gini = 0.0\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.012641559125625495, 0.8357142857142857, 'gini = 0.0\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.013695022386094284, 0.85, 'gini = 0.0\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.01685541216750066, 0.8642857142857143, 'Partner_encode <= 0.5\ngini = 0.426\nsamples = 17\nvalue = [7, 10]'),
#  Text(0.015801948907031866, 0.85, 'PaperlessBilling_encode <= 0.5\ngini = 0.484\nsamples = 14\nvalue = [5, 9]'),
#  Text(0.014748485646563076, 0.8357142857142857, 'TotalCharges <= 20.175\ngini = 0.486\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.013695022386094284, 0.8214285714285714, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.015801948907031866, 0.8214285714285714, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.01685541216750066, 0.8357142857142857, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.01790887542796945, 0.85, 'gini = nan\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.01685541216750066, 0.8785714285714286, 'gini = nan\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.01790887542796945, 0.8928571428571429, 'gini = 0.0\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.028443508032657362, 0.9214285714285714, 'MonthlyCharges <= 20.475\ngini = 0.245\nsamples = 91\nvalue = [78, 13]'),
#  Text(0.023176191730313406, 0.9071428571428571, 'MonthlyCharges <= 19.875\ngini = 0.195\nsamples = 69\nvalue = [62, 7]'),
#  Text(0.022122728469844616, 0.8928571428571429, 'TotalCharges <= 36.55\ngini = 0.358\nsamples = 30\nvalue = [23, 7]'),
#  Text(0.020015801948907033, 0.8785714285714286, 'gender_encode <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.01896233868843824, 0.8642857142857143, 'gini = -1.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.021069265209375822, 0.8642857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.024229654990782196, 0.8785714285714286, 'TotalCharges <= 57.675\ngini = 0.26\nsamples = 26\nvalue = [22, 4]'),
#  Text(0.023176191730313406, 0.8642857142857143, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.02528311825125099, 0.8642857142857143, 'TotalCharges <= 60.2\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.024229654990782196, 0.85, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.02633658151171978, 0.85, 'MonthlyCharges <= 19.575\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.02528311825125099, 0.8357142857142857, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.02739004477218857, 0.8357142857142857, 'MonthlyCharges <= 19.625\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.02633658151171978, 0.8214285714285714, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.028443508032657362, 0.8214285714285714, 'gini = 0.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.024229654990782196, 0.8928571428571429, 'gini = 0.0\nsamples = 39\nvalue = [39, 0]'),
#  Text(0.03371082433500132, 0.9071428571428571, 'TotalCharges <= 20.575\ngini = 0.401\nsamples = 22\nvalue = [16, 6]'),
#  Text(0.03160389781406373, 0.8928571428571429, 'gender_encode <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.030550434553594942, 0.8785714285714286, 'TotalCharges <= 20.525\ngini = 0.444\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.029496971293126152, 0.8642857142857143, 'PaperlessBilling_encode <= 0.5\ngini = 0.375\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.028443508032657362, 0.85, 'gini = 0.444\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.030550434553594942, 0.85, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03160389781406373, 0.8642857142857143, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03265736107453253, 0.8785714285714286, 'gini = nan\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0358177508559389, 0.8928571428571429, 'TotalCharges <= 36.15\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.03476428759547011, 0.8785714285714286, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.03687121411640769, 0.8785714285714286, 'TotalCharges <= 39.275\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.0358177508559389, 0.8642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03792467737687648, 0.8642857142857143, 'MonthlyCharges <= 20.625\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.03687121411640769, 0.85, 'TotalCharges <= 54.275\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.0358177508559389, 0.8357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03792467737687648, 0.8357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.038978140637345275, 0.85, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.0597181985778246, 0.9357142857142857, 'TotalCharges <= 169.975\ngini = 0.499\nsamples = 315\nvalue = [150, 165]'),
#  Text(0.05148801685541217, 0.9214285714285714, 'PaperlessBilling_encode <= 0.5\ngini = 0.497\nsamples = 301\nvalue = [138, 163]'),
#  Text(0.04424545693968923, 0.9071428571428571, 'MonthlyCharges <= 61.6\ngini = 0.496\nsamples = 141\nvalue = [77, 64]'),
#  Text(0.043191993679220435, 0.8928571428571429, 'TotalCharges <= 152.8\ngini = 0.495\nsamples = 136\nvalue = [77, 59]'),
#  Text(0.042138530418751645, 0.8785714285714286, 'TotalCharges <= 89.775\ngini = 0.491\nsamples = 132\nvalue = [75, 57]'),
#  Text(0.041085067158282855, 0.8642857142857143, 'gini = 0.496\nsamples = 106\nvalue = [56, 50]'),
#  Text(0.043191993679220435, 0.8642857142857143, 'gender_encode <= 0.5\ngini = 0.434\nsamples = 26\nvalue = [19, 7]'),
#  Text(0.042138530418751645, 0.85, 'PhoneService_encode <= 0.5\ngini = 0.465\nsamples = 15\nvalue = [8, 7]'),
#  Text(0.040031603897814065, 0.8357142857142857, 'Partner_encode <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.038978140637345275, 0.8214285714285714, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.041085067158282855, 0.8214285714285714, 'gini = nan\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04424545693968923, 0.8357142857142857, 'Partner_encode <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.043191993679220435, 0.8214285714285714, 'tenure <= 2.5\ngini = 0.494\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.042138530418751645, 0.8071428571428572, 'SeniorCitizen <= 0.5\ngini = 0.408\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.041085067158282855, 0.7928571428571428, 'gini = 0.32\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.043191993679220435, 0.7928571428571428, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04424545693968923, 0.8071428571428572, 'gini = nan\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04529892020015802, 0.8214285714285714, 'gini = nan\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04424545693968923, 0.85, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.04424545693968923, 0.8785714285714286, 'gini = nan\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.04529892020015802, 0.8928571428571429, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.05873057677113511, 0.9071428571428571, 'PhoneService_encode <= 0.5\ngini = 0.472\nsamples = 160\nvalue = [61, 99]'),
#  Text(0.05372662628390835, 0.8928571428571429, 'tenure <= 2.5\ngini = 0.289\nsamples = 40\nvalue = [7, 33]'),
#  Text(0.05161969976297077, 0.8785714285714286, 'Partner_encode <= 0.5\ngini = 0.278\nsamples = 32\nvalue = [4, 28]'),
#  Text(0.05056623650250198, 0.8642857142857143, 'MonthlyCharges <= 40.025\ngini = 0.124\nsamples = 26\nvalue = [2, 24]'),
#  Text(0.04951277324203318, 0.85, 'Dependents_encode <= 0.5\ngini = 0.142\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.04845930998156439, 0.8357142857142857, 'TotalCharges <= 51.925\ngini = 0.165\nsamples = 21\nvalue = [2, 19]'),
#  Text(0.0474058467210956, 0.8214285714285714, 'TotalCharges <= 35.65\ngini = 0.172\nsamples = 17\nvalue = [2, 15]'),
#  Text(0.04635238346062681, 0.8071428571428572, 'gender_encode <= 0.5\ngini = 0.208\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.04529892020015802, 0.7928571428571428, 'gini = -1.92\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.0474058467210956, 0.7928571428571428, 'SeniorCitizen <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.04635238346062681, 0.7785714285714286, 'TotalCharges <= 24.8\ngini = 0.219\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.04529892020015802, 0.7642857142857142, 'gini = -4.0\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0474058467210956, 0.7642857142857142, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.04845930998156439, 0.7785714285714286, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04845930998156439, 0.8071428571428572, 'gini = nan\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.04951277324203318, 0.8214285714285714, 'gini = nan\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.05056623650250198, 0.8357142857142857, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05161969976297077, 0.85, 'gini = nan\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.05267316302343956, 0.8642857142857143, 'gini = 0.0\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.05583355280484593, 0.8785714285714286, 'SeniorCitizen <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.05478008954437714, 0.8642857142857143, 'MonthlyCharges <= 30.375\ngini = 0.469\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.05372662628390835, 0.85, 'gini = -12.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05583355280484593, 0.85, 'gini = 0.0\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.056887016065314724, 0.8642857142857143, 'gini = nan\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06373452725836186, 0.8928571428571429, 'MonthlyCharges <= 68.125\ngini = 0.495\nsamples = 120\nvalue = [54, 66]'),
#  Text(0.06268106399789307, 0.8785714285714286, 'Partner_encode <= 0.5\ngini = 0.495\nsamples = 116\nvalue = [54, 62]'),
#  Text(0.058993942586252304, 0.8642857142857143, 'MonthlyCharges <= 60.675\ngini = 0.495\nsamples = 98\nvalue = [44, 54]'),
#  Text(0.057940479325783514, 0.85, 'Dependents_encode <= 0.5\ngini = 0.495\nsamples = 94\nvalue = [42, 52]'),
#  Text(0.05583355280484593, 0.8357142857142857, 'TotalCharges <= 140.95\ngini = 0.494\nsamples = 86\nvalue = [36, 50]'),
#  Text(0.05478008954437714, 0.8214285714285714, 'tenure <= 2.5\ngini = 0.487\nsamples = 82\nvalue = [33, 49]'),
#  Text(0.05372662628390835, 0.8071428571428572, 'TotalCharges <= 111.675\ngini = 0.481\nsamples = 80\nvalue = [32, 48]'),
#  Text(0.05267316302343956, 0.7928571428571428, 'TotalCharges <= 104.175\ngini = 0.48\nsamples = 76\nvalue = [30, 46]'),
#  Text(0.05161969976297077, 0.7785714285714286, 'MonthlyCharges <= 55.575\ngini = 0.478\nsamples = 72\nvalue = [28, 44]'),
#  Text(0.05056623650250198, 0.7642857142857142, 'TotalCharges <= 93.225\ngini = 0.475\nsamples = 68\nvalue = [28, 40]'),
#  Text(0.04951277324203318, 0.75, 'SeniorCitizen <= 0.5\ngini = 0.484\nsamples = 64\nvalue = [28, 36]'),
#  Text(0.04845930998156439, 0.7357142857142858, 'tenure <= 1.5\ngini = 0.492\nsamples = 61\nvalue = [27, 34]'),
#  Text(0.04635238346062681, 0.7214285714285714, 'MonthlyCharges <= 54.825\ngini = 0.49\nsamples = 54\nvalue = [23, 31]'),
#  Text(0.04529892020015802, 0.7071428571428572, 'MonthlyCharges <= 52.85\ngini = 0.489\nsamples = 50\nvalue = [21, 29]'),
#  Text(0.04424545693968923, 0.6928571428571428, 'TotalCharges <= 50.6\ngini = 0.487\nsamples = 46\nvalue = [21, 25]'),
#  Text(0.043191993679220435, 0.6785714285714286, 'TotalCharges <= 50.125\ngini = 0.496\nsamples = 42\nvalue = [20, 22]'),
#  Text(0.042138530418751645, 0.6642857142857143, 'MonthlyCharges <= 49.85\ngini = 0.499\nsamples = 38\nvalue = [18, 20]'),
#  Text(0.041085067158282855, 0.65, 'TotalCharges <= 48.575\ngini = 0.499\nsamples = 34\nvalue = [16, 18]'),
#  Text(0.040031603897814065, 0.6357142857142857, 'TotalCharges <= 45.75\ngini = 0.498\nsamples = 30\nvalue = [14, 16]'),
#  Text(0.038978140637345275, 0.6214285714285714, 'MonthlyCharges <= 45.0\ngini = 0.498\nsamples = 26\nvalue = [12, 14]'),
#  Text(0.03687121411640769, 0.6071428571428571, 'MonthlyCharges <= 44.5\ngini = 0.499\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.0358177508559389, 0.5928571428571429, 'gender_encode <= 0.5\ngini = 0.459\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.03476428759547011, 0.5785714285714286, 'gini = -0.625\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.03687121411640769, 0.5785714285714286, 'gini = 0.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.03792467737687648, 0.5928571428571429, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.041085067158282855, 0.6071428571428571, 'MonthlyCharges <= 45.625\ngini = 0.408\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.040031603897814065, 0.5928571428571429, 'MonthlyCharges <= 45.35\ngini = 0.298\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.038978140637345275, 0.5785714285714286, 'gini = -2.222\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.041085067158282855, 0.5785714285714286, 'gini = 0.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.042138530418751645, 0.5928571428571429, 'gini = nan\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.041085067158282855, 0.6214285714285714, 'gini = nan\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.042138530418751645, 0.6357142857142857, 'gini = nan\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.043191993679220435, 0.65, 'gini = nan\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.04424545693968923, 0.6642857142857143, 'gini = nan\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.04529892020015802, 0.6785714285714286, 'gini = nan\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.04635238346062681, 0.6928571428571428, 'gini = nan\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.0474058467210956, 0.7071428571428572, 'gini = nan\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.05056623650250198, 0.7214285714285714, 'gender_encode <= 0.5\ngini = 0.444\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.04951277324203318, 0.7071428571428572, 'gini = 0.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.05161969976297077, 0.7071428571428572, 'MonthlyCharges <= 46.3\ngini = 0.32\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.05056623650250198, 0.6928571428571428, 'gini = -4.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05267316302343956, 0.6928571428571428, 'gini = 0.0\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.05056623650250198, 0.7357142857142858, 'gini = nan\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.05161969976297077, 0.75, 'gini = nan\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.05267316302343956, 0.7642857142857142, 'gini = nan\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.05372662628390835, 0.7785714285714286, 'gini = nan\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.05478008954437714, 0.7928571428571428, 'gini = nan\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.05583355280484593, 0.8071428571428572, 'gini = nan\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.056887016065314724, 0.8214285714285714, 'gini = nan\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.060047405846721094, 0.8357142857142857, 'MonthlyCharges <= 49.975\ngini = 0.5\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.058993942586252304, 0.8214285714285714, 'gini = 0.5\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.061100869107189884, 0.8214285714285714, 'gini = 0.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.060047405846721094, 0.85, 'gini = nan\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.06636818540953385, 0.8642857142857143, 'tenure <= 1.5\ngini = 0.49\nsamples = 18\nvalue = [10, 8]'),
#  Text(0.06531472214906506, 0.85, 'SeniorCitizen <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.06426125888859625, 0.8357142857142857, 'TotalCharges <= 45.35\ngini = 0.469\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.06320779562812746, 0.8214285714285714, 'gini = -0.889\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06531472214906506, 0.8214285714285714, 'gini = 0.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.06636818540953385, 0.8357142857142857, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06742164867000264, 0.85, 'gini = 0.18\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.06478799051883066, 0.8785714285714286, 'gini = nan\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.06794838030023703, 0.9214285714285714, 'MonthlyCharges <= 55.675\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.06689491703976824, 0.9071428571428571, 'Dependents_encode <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.06584145377929945, 0.8928571428571429, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06794838030023703, 0.8928571428571429, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.06900184356070582, 0.9071428571428571, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.09461416908085331, 0.95, 'MonthlyCharges <= 20.925\ngini = 0.311\nsamples = 640\nvalue = [517, 123]'),
#  Text(0.07374242823281538, 0.9357142857142857, 'MonthlyCharges <= 20.375\ngini = 0.164\nsamples = 233\nvalue = [212, 21]'),
#  Text(0.07268896497234659, 0.9214285714285714, 'gender_encode <= 0.5\ngini = 0.197\nsamples = 187\nvalue = [166, 21]'),
#  Text(0.0716355017118778, 0.9071428571428571, 'TotalCharges <= 80.2\ngini = 0.273\nsamples = 95\nvalue = [80, 15]'),
#  Text(0.07058203845140901, 0.8928571428571429, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.07268896497234659, 0.8928571428571429, 'TotalCharges <= 107.425\ngini = 0.243\nsamples = 92\nvalue = [79, 13]'),
#  Text(0.0716355017118778, 0.8785714285714286, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.07374242823281538, 0.8785714285714286, 'TotalCharges <= 108.625\ngini = 0.272\nsamples = 80\nvalue = [67, 13]'),
#  Text(0.07268896497234659, 0.8642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07479589149328417, 0.8642857142857143, 'TotalCharges <= 167.875\ngini = 0.258\nsamples = 79\nvalue = [67, 12]'),
#  Text(0.07058203845140901, 0.85, 'TotalCharges <= 144.975\ngini = 0.386\nsamples = 23\nvalue = [17, 6]'),
#  Text(0.06847511193047143, 0.8357142857142857, 'TotalCharges <= 133.575\ngini = 0.298\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.06742164867000264, 0.8214285714285714, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.06952857519094022, 0.8214285714285714, 'TotalCharges <= 139.275\ngini = 0.5\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.06847511193047143, 0.8071428571428572, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07058203845140901, 0.8071428571428572, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.07268896497234659, 0.8357142857142857, 'MonthlyCharges <= 19.35\ngini = 0.444\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.0716355017118778, 0.8214285714285714, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.07374242823281538, 0.8214285714285714, 'TotalCharges <= 158.15\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.07268896497234659, 0.8071428571428572, 'TotalCharges <= 146.45\ngini = 0.469\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.0716355017118778, 0.7928571428571428, 'gini = -1.5\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07374242823281538, 0.7928571428571428, 'gini = 0.0\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.07479589149328417, 0.8071428571428572, 'gini = nan\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.07900974453515934, 0.85, 'MonthlyCharges <= 19.275\ngini = 0.191\nsamples = 56\nvalue = [50, 6]'),
#  Text(0.07690281801422176, 0.8357142857142857, 'Dependents_encode <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.07584935475375296, 0.8214285714285714, 'gini = -4.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07795628127469055, 0.8214285714285714, 'gini = 0.0\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.08111667105609692, 0.8357142857142857, 'TotalCharges <= 221.075\ngini = 0.142\nsamples = 52\nvalue = [48, 4]'),
#  Text(0.08006320779562813, 0.8214285714285714, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.08217013431656571, 0.8214285714285714, 'TotalCharges <= 222.475\ngini = 0.213\nsamples = 33\nvalue = [29, 4]'),
#  Text(0.08111667105609692, 0.8071428571428572, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0832235975770345, 0.8071428571428572, 'MonthlyCharges <= 19.85\ngini = 0.17\nsamples = 32\nvalue = [29, 3]'),
#  Text(0.08217013431656571, 0.7928571428571428, 'gini = 0.236\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.08427706083750329, 0.7928571428571428, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.07374242823281538, 0.9071428571428571, 'gini = 0.106\nsamples = 92\nvalue = [86, 6]'),
#  Text(0.07479589149328417, 0.9214285714285714, 'gini = 0.0\nsamples = 46\nvalue = [46, 0]'),
#  Text(0.11548590992889123, 0.9357142857142857, 'TotalCharges <= 310.9\ngini = 0.376\nsamples = 407\nvalue = [305, 102]'),
#  Text(0.095206742164867, 0.9214285714285714, 'MonthlyCharges <= 54.45\ngini = 0.455\nsamples = 154\nvalue = [100, 54]'),
#  Text(0.09415327890439822, 0.9071428571428571, 'Dependents_encode <= 0.5\ngini = 0.473\nsamples = 135\nvalue = [83, 52]'),
#  Text(0.09007110877008165, 0.8928571428571429, 'MonthlyCharges <= 30.175\ngini = 0.495\nsamples = 93\nvalue = [51, 42]'),
#  Text(0.08796418224914405, 0.8785714285714286, 'TotalCharges <= 98.125\ngini = 0.438\nsamples = 37\nvalue = [25, 12]'),
#  Text(0.08691071898867526, 0.8642857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08901764550961286, 0.8642857142857143, 'MonthlyCharges <= 24.2\ngini = 0.389\nsamples = 34\nvalue = [25, 9]'),
#  Text(0.08638398735844087, 0.85, 'Partner_encode <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.08533052409797208, 0.8357142857142857, 'MonthlyCharges <= 21.125\ngini = 0.49\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.08427706083750329, 0.8214285714285714, 'gini = -1.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08638398735844087, 0.8214285714285714, 'gini = 0.0\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.08743745061890966, 0.8357142857142857, 'gini = nan\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09165130366078483, 0.85, 'MonthlyCharges <= 27.075\ngini = 0.302\nsamples = 27\nvalue = [22, 5]'),
#  Text(0.08954437713984725, 0.8357142857142857, 'TotalCharges <= 101.15\ngini = 0.266\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.08849091387937846, 0.8214285714285714, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09059784040031604, 0.8214285714285714, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.09375823018172241, 0.8357142857142857, 'MonthlyCharges <= 29.7\ngini = 0.375\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.09270476692125362, 0.8214285714285714, 'SeniorCitizen <= 0.5\ngini = 0.463\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.09165130366078483, 0.8071428571428572, 'TotalCharges <= 221.7\ngini = 0.5\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.09059784040031604, 0.7928571428571428, 'gini = 0.5\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09270476692125362, 0.7928571428571428, 'gini = 0.0\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.09375823018172241, 0.8071428571428572, 'gini = nan\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.0948116934421912, 0.8214285714285714, 'gini = nan\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.09217803529101923, 0.8785714285714286, 'MonthlyCharges <= 51.175\ngini = 0.497\nsamples = 56\nvalue = [26, 30]'),
#  Text(0.09112457203055044, 0.8642857142857143, 'gini = 0.496\nsamples = 52\nvalue = [24, 28]'),
#  Text(0.09323149855148802, 0.8642857142857143, 'gini = 0.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.09823544903871477, 0.8928571428571429, 'MonthlyCharges <= 25.45\ngini = 0.355\nsamples = 42\nvalue = [32, 10]'),
#  Text(0.09718198577824598, 0.8785714285714286, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0
285714286, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.21465548459309983, 0.9642857142857143, 'TotalCharges <= 118.1\ngini = 0.454\nsamples = 906\nvalue = [317, 589]'),
#  Text(0.1688833289439031, 0.95, 'TotalCharges <= 75.675\ngini = 0.298\nsamples = 181\nvalue = [33, 148]'),
#  Text(0.15815117197787726, 0.9357142857142857, 'TotalCharges <= 69.875\ngini = 0.365\nsamples = 99\nvalue = [24, 75]'),
#  Text(0.15709770871740847, 0.9214285714285714, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(0.15920463523834608, 0.9214285714285714, 'MonthlyCharges <= 75.475\ngini = 0.42\nsamples = 80\nvalue = [24, 56]'),
#  Text(0.15815117197787726, 0.9071428571428571, 'PaperlessBilling_encode <= 0.5\ngini = 0.413\nsamples = 78\nvalue = [22, 56]'),
#  Text(0.1527521727679747, 0.8928571428571429, 'TotalCharges <= 73.75\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.15064524624703712, 0.8785714285714286, 'SeniorCitizen <= 0.5\ngini = 0.375\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.14959178298656833, 0.8642857142857143, 'Partner_encode <= 0.5\ngini = 0.298\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.14853831972609954, 0.85, 'TotalCharges <= 70.25\ngini = 0.32\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.14748485646563075, 0.8357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14959178298656833, 0.8357142857142857, 'MonthlyCharges <= 72.425\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.14853831972609954, 0.8214285714285714, 'TotalCharges <= 71.225\ngini = 0.219\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.14748485646563075, 0.8071428571428572, 'TotalCharges <= 71.0\ngini = 0.245\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.14643139320516196, 0.7928571428571428, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.14853831972609954, 0.7928571428571428, 'gini = 0.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14959178298656833, 0.8071428571428572, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15064524624703712, 0.8214285714285714, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15064524624703712, 0.85, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1516987095075059, 0.8642857142857143, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1548590992889123, 0.8785714285714286, 'TotalCharges <= 75.0\ngini = 0.375\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.15380563602844352, 0.8642857142857143, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.1559125625493811, 0.8642857142857143, 'gini = 0.0\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1635501711877798, 0.8928571428571429, 'MonthlyCharges <= 72.825\ngini = 0.348\nsamples = 58\nvalue = [13, 45]'),
#  Text(0.16065314722149066, 0.8785714285714286, 'gender_encode <= 0.5\ngini = 0.451\nsamples = 31\nvalue = [11, 20]'),
#  Text(0.15801948907031868, 0.8642857142857143, 'MonthlyCharges <= 71.2\ngini = 0.401\nsamples = 17\nvalue = [5, 12]'),
#  Text(0.1569660258098499, 0.85, 'TotalCharges <= 71.075\ngini = 0.375\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.1559125625493811, 0.8357142857142857, 'Dependents_encode <= 0.5\ngini = 0.32\nsamples = 14\nvalue = [3, 11]'),
#  Text(0.1548590992889123, 0.8214285714285714, 'TotalCharges <= 70.65\ngini = 0.337\nsamples = 13\nvalue = [3, 10]'),
#  Text(0.15380563602844352, 0.8071428571428572, 'Partner_encode <= 0.5\ngini = 0.278\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.1527521727679747, 0.7928571428571428, 'gini = 0.298\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.1548590992889123, 0.7928571428571428, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1559125625493811, 0.8071428571428572, 'gini = 0.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1569660258098499, 0.8214285714285714, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15801948907031868, 0.8357142857142857, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15907295233078747, 0.85, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16328680537266263, 0.8642857142857143, 'SeniorCitizen <= 0.5\ngini = 0.497\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.16223334211219384, 0.85, 'MonthlyCharges <= 71.075\ngini = 0.497\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.16117987885172505, 0.8357142857142857, 'Dependents_encode <= 0.5\ngini = 0.496\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.15907295233078747, 0.8214285714285714, 'MonthlyCharges <= 70.2\ngini = 0.49\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.15801948907031868, 0.8071428571428572, 'TotalCharges <= 69.975\ngini = 0.48\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.1569660258098499, 0.7928571428571428, 'gini = 0.375\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.15907295233078747, 0.7928571428571428, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16012641559125626, 0.8071428571428572, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16328680537266263, 0.8214285714285714, 'MonthlyCharges <= 69.975\ngini = 0.444\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.16223334211219384, 0.8071428571428572, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16434026863313142, 0.8071428571428572, 'Partner_encode <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.16328680537266263, 0.7928571428571428, 'gini = 0.444\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1653937318936002, 0.7928571428571428, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16328680537266263, 0.8357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.16434026863313142, 0.85, 'gini = 0.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.166447195154069, 0.8785714285714286, 'TotalCharges <= 75.4\ngini = 0.142\nsamples = 27\nvalue = [2, 25]'),
#  Text(0.1653937318936002, 0.8642857142857143, 'gini = 0.137\nsamples = 26\nvalue = [2, 24]'),
#  Text(0.1675006584145378, 0.8642857142857143, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16025809849881487, 0.9071428571428571, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1796154859099289, 0.9357142857142857, 'tenure <= 1.5\ngini = 0.198\nsamples = 82\nvalue = [9, 73]'),
#  Text(0.1785620226494601, 0.9214285714285714, 'TotalCharges <= 101.625\ngini = 0.195\nsamples = 81\nvalue = [9, 72]'),
#  Text(0.17750855938899132, 0.9071428571428571, 'Dependents_encode <= 0.5\ngini = 0.198\nsamples = 80\nvalue = [9, 71]'),
#  Text(0.17487490123781932, 0.8928571428571429, 'TotalCharges <= 100.525\ngini = 0.157\nsamples = 69\nvalue = [6, 63]'),
#  Text(0.17382143797735053, 0.8785714285714286, 'TotalCharges <= 98.05\ngini = 0.159\nsamples = 68\nvalue = [6, 62]'),
#  Text(0.17276797471688174, 0.8642857142857143, 'TotalCharges <= 95.75\ngini = 0.161\nsamples = 67\nvalue = [6, 61]'),
#  Text(0.17171451145641295, 0.85, 'MonthlyCharges <= 95.625\ngini = 0.163\nsamples = 66\nvalue = [5, 61]'),
#  Text(0.17066104819594416, 0.8357142857142857, 'TotalCharges <= 95.35\ngini = 0.14\nsamples = 65\nvalue = [5, 60]'),
#  Text(0.16960758493547537, 0.8214285714285714, 'TotalCharges <= 95.05\ngini = 0.142\nsamples = 64\nvalue = [5, 59]'),
#  Text(0.16855412167500658, 0.8071428571428572, 'MonthlyCharges <= 94.8\ngini = 0.144\nsamples = 63\nvalue = [5, 58]'),
#  Text(0.1675006584145378, 0.7928571428571428, 'TotalCharges <= 94.3\ngini = 0.146\nsamples = 62\nvalue = [5, 57]'),
#  Text(0.166447195154069, 0.7785714285714286, 'TotalCharges <= 93.925\ngini = 0.148\nsamples = 61\nvalue = [5, 56]'),
#  Text(0.1653937318936002, 0.7642857142857142, 'TotalCharges <= 93.7\ngini = 0.15\nsamples = 60\nvalue = [5, 55]'),
#  Text(0.16434026863313142, 0.75, 'MonthlyCharges <= 92.625\ngini = 0.153\nsamples = 59\nvalue = [5, 54]'),
#  Text(0.16328680537266263, 0.7357142857142858, 'MonthlyCharges <= 91.5\ngini = 0.155\nsamples = 58\nvalue = [5, 53]'),
#  Text(0.16223334211219384, 0.7214285714285714, 'MonthlyCharges <= 91.075\ngini = 0.158\nsamples = 57\nvalue = [5, 52]'),
#  Text(0.16117987885172505, 0.7071428571428572, 'MonthlyCharges <= 90.8\ngini = 0.16\nsamples = 56\nvalue = [5, 51]'),
#  Text(0.16012641559125626, 0.6928571428571428, 'MonthlyCharges <= 90.675\ngini = 0.163\nsamples = 55\nvalue = [5, 50]'),
#  Text(0.15907295233078747, 0.6785714285714286, 'TotalCharges <= 90.575\ngini = 0.165\nsamples = 54\nvalue = [5, 49]'),
#  Text(0.15801948907031868, 0.6642857142857143, 'PaperlessBilling_encode <= 0.5\ngini = 0.168\nsamples = 53\nvalue = [5, 48]'),
#  Text(0.1569660258098499, 0.65, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.15907295233078747, 0.65, 'MonthlyCharges <= 90.225\ngini = 0.219\nsamples = 40\nvalue = [5, 35]'),
#  Text(0.15801948907031868, 0.6357142857142857, 'TotalCharges <= 89.725\ngini = 0.219\nsamples = 39\nvalue = [5, 34]'),
#  Text(0.1569660258098499, 0.6214285714285714, 'TotalCharges <= 89.4\ngini = 0.224\nsamples = 38\nvalue = [5, 33]'),
#  Text(0.1559125625493811, 0.6071428571428571, 'TotalCharges <= 89.175\ngini = 0.229\nsamples = 37\nvalue = [5, 32]'),
#  Text(0.1548590992889123, 0.5928571428571429, 'TotalCharges <= 88.95\ngini = 0.234\nsamples = 36\nvalue = [4, 32]'),
#  Text(0.15380563602844352, 0.5785714285714286, 'TotalCharges <= 88.575\ngini = 0.198\nsamples = 35\nvalue = [4, 31]'),
#  Text(0.1527521727679747, 0.5642857142857143, 'MonthlyCharges <= 87.475\ngini = 0.202\nsamples = 34\nvalue = [4, 30]'),
#  Text(0.1516987095075059, 0.55, 'MonthlyCharges <= 86.325\ngini = 0.208\nsamples = 33\nvalue = [4, 29]'),
#  Text(0.15064524624703712, 0.5357142857142857, 'TotalCharges <= 85.875\ngini = 0.213\nsamples = 32\nvalue = [4, 28]'),
#  Text(0.14959178298656833, 0.5214285714285715, 'MonthlyCharges <= 85.625\ngini = 0.219\nsamples = 31\nvalue = [4, 27]'),
#  Text(0.14853831972609954, 0.5071428571428571, 'TotalCharges <= 85.5\ngini = 0.225\nsamples = 30\nvalue = [4, 26]'),
#  Text(0.14748485646563075, 0.4928571428571429, 'TotalCharges <= 84.625\ngini = 0.231\nsamples = 29\nvalue = [4, 25]'),
#  Text(0.14643139320516196, 0.4785714285714286, 'MonthlyCharges <= 82.675\ngini = 0.278\nsamples = 23\nvalue = [4, 19]'),
#  Text(0.14432446668422438, 0.4642857142857143, 'TotalCharges <= 81.825\ngini = 0.245\nsamples = 20\nvalue = [2, 18]'),
#  Text(0.1432710034237556, 0.45, 'MonthlyCharges <= 81.4\ngini = 0.18\nsamples = 19\nvalue = [2, 17]'),
#  Text(0.1422175401632868, 0.4357142857142857, 'TotalCharges <= 80.975\ngini = 0.188\nsamples = 18\nvalue = [2, 16]'),
#  Text(0.14116407690281801, 0.42142857142857143, 'MonthlyCharges <= 80.7\ngini = 0.198\nsamples = 17\nvalue = [2, 15]'),
#  Text(0.14011061364234922, 0.40714285714285714, 'gini = 0.208\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.1422175401632868, 0.40714285714285714, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1432710034237556, 0.42142857142857143, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14432446668422438, 0.4357142857142857, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14537792994469317, 0.45, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14853831972609954, 0.4642857142857143, 'MonthlyCharges <= 84.0\ngini = 0.5\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.14748485646563075, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14959178298656833, 0.45, 'gender_encode <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14853831972609954, 0.4357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15064524624703712, 0.4357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14853831972609954, 0.4785714285714286, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.14959178298656833, 0.4928571428571429, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15064524624703712, 0.5071428571428571, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1516987095075059, 0.5214285714285715, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1527521727679747, 0.5357142857142857, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15380563602844352, 0.55, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1548590992889123, 0.5642857142857143, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3463260468791151, 0.7357142857142858, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3452725836186463, 0.7642857142857142, 'gini = nan\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3452725836186463, 0.7928571428571428, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.34211219383723995, 0.8214285714285714, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.354227021332631, 0.85, 'Dependents_encode <= 0.5\ngini = 0.496\nsamples = 34\nvalue = [19, 15]'),
#  Text(0.3531735580721622, 0.8357142857142857, 'tenure <= 12.5\ngini = 0.5\nsamples = 29\nvalue = [15, 14]'),
#  Text(0.35053989992099027, 0.8214285714285714, 'MonthlyCharges <= 80.2\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.3484329734000527, 0.8071428571428572, 'TotalCharges <= 915.6\ngini = 0.32\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.3473795101395839, 0.7928571428571428, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3494864366605215, 0.7928571428571428, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.35264682644192785, 0.8071428571428572, 'TotalCharges <= 931.1\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.35159336318145906, 0.7928571428571428, 'MonthlyCharges <= 80.975\ngini = 0.5\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.35053989992099027, 0.7785714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.35264682644192785, 0.7785714285714286, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.35370028970239664, 0.7928571428571428, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3558072162233342, 0.8214285714285714, 'MonthlyCharges <= 79.9\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.35475375296286543, 0.8071428571428572, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.356860679483803, 0.8071428571428572, 'TotalCharges <= 1018.8\ngini = 0.498\nsamples = 15\nvalue = [8, 7]'),
#  Text(0.3558072162233342, 0.7928571428571428, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3579141427442718, 0.7928571428571428, 'TotalCharges <= 1059.35\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.356860679483803, 0.7785714285714286, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3589676060047406, 0.7785714285714286, 'TotalCharges <= 1092.15\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.3579141427442718, 0.7642857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3600210692652094, 0.7642857142857142, 'gender_encode <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.3579141427442718, 0.75, 'TotalCharges <= 1194.15\ngini = 0.444\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.356860679483803, 0.7357142857142858, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3589676060047406, 0.7357142857142858, 'TotalCharges <= 1305.525\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3579141427442718, 0.7214285714285714, 'TotalCharges <= 1280.475\ngini = 0.444\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.356860679483803, 0.7071428571428572, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3589676060047406, 0.7071428571428572, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3600210692652094, 0.7214285714285714, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36212799578614696, 0.75, 'MonthlyCharges <= 80.375\ngini = 0.5\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.36107453252567817, 0.7357142857142858, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36318145904661575, 0.7357142857142858, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3552804845930998, 0.8357142857142857, 'gini = 0.0\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.39643139320516196, 0.9071428571428571, 'Dependents_encode <= 0.5\ngini = 0.373\nsamples = 262\nvalue = [65, 197]'),
#  Text(0.3885962602054253, 0.8928571428571429, 'MonthlyCharges <= 95.95\ngini = 0.346\nsamples = 228\nvalue = [51, 177]'),
#  Text(0.37713984724782723, 0.8785714285714286, 'TotalCharges <= 956.675\ngini = 0.39\nsamples = 157\nvalue = [42, 115]'),
#  Text(0.37476955491177244, 0.8642857142857143, 'tenure <= 10.5\ngini = 0.332\nsamples = 113\nvalue = [24, 89]'),
#  Text(0.37371609165130365, 0.85, 'TotalCharges <= 943.775\ngini = 0.335\nsamples = 112\nvalue = [24, 88]'),
#  Text(0.37266262839083486, 0.8357142857142857, 'TotalCharges <= 924.2\ngini = 0.337\nsamples = 111\nvalue = [24, 87]'),
#  Text(0.37160916513036607, 0.8214285714285714, 'MonthlyCharges <= 95.75\ngini = 0.339\nsamples = 110\nvalue = [24, 86]'),
#  Text(0.3705557018698973, 0.8071428571428572, 'TotalCharges <= 906.325\ngini = 0.341\nsamples = 109\nvalue = [23, 86]'),
#  Text(0.3695022386094285, 0.7928571428571428, 'TotalCharges <= 894.475\ngini = 0.333\nsamples = 108\nvalue = [23, 85]'),
#  Text(0.3684487753489597, 0.7785714285714286, 'TotalCharges <= 890.25\ngini = 0.335\nsamples = 107\nvalue = [23, 84]'),
#  Text(0.3673953120884909, 0.7642857142857142, 'MonthlyCharges <= 95.55\ngini = 0.337\nsamples = 106\nvalue = [23, 83]'),
#  Text(0.3663418488280221, 0.75, 'TotalCharges <= 877.5\ngini = 0.34\nsamples = 105\nvalue = [23, 82]'),
#  Text(0.36528838556755333, 0.7357142857142858, 'TotalCharges <= 864.1\ngini = 0.342\nsamples = 104\nvalue = [23, 81]'),
#  Text(0.36423492230708454, 0.7214285714285714, 'Partner_encode <= 0.5\ngini = 0.344\nsamples = 103\nvalue = [22, 81]'),
#  Text(0.36212799578614696, 0.7071428571428572, 'MonthlyCharges <= 95.475\ngini = 0.299\nsamples = 81\nvalue = [15, 66]'),
#  Text(0.36107453252567817, 0.6928571428571428, 'TotalCharges <= 848.6\ngini = 0.302\nsamples = 80\nvalue = [15, 65]'),
#  Text(0.3600210692652094, 0.6785714285714286, 'TotalCharges <= 833.075\ngini = 0.305\nsamples = 79\nvalue = [15, 64]'),
#  Text(0.3589676060047406, 0.6642857142857143, 'TotalCharges <= 781.125\ngini = 0.308\nsamples = 78\nvalue = [15, 63]'),
#  Text(0.3579141427442718, 0.65, 'MonthlyCharges <= 95.4\ngini = 0.284\nsamples = 75\nvalue = [13, 62]'),
#  Text(0.356860679483803, 0.6357142857142857, 'MonthlyCharges <= 95.25\ngini = 0.287\nsamples = 74\nvalue = [13, 61]'),
#  Text(0.3558072162233342, 0.6214285714285714, 'MonthlyCharges <= 95.125\ngini = 0.29\nsamples = 73\nvalue = [13, 60]'),
#  Text(0.35475375296286543, 0.6071428571428571, 'TotalCharges <= 768.075\ngini = 0.293\nsamples = 72\nvalue = [13, 59]'),
#  Text(0.35370028970239664, 0.5928571428571429, 'TotalCharges <= 762.3\ngini = 0.296\nsamples = 71\nvalue = [13, 58]'),
#  Text(0.35264682644192785, 0.5785714285714286, 'TotalCharges <= 760.35\ngini = 0.299\nsamples = 70\nvalue = [13, 57]'),
#  Text(0.35159336318145906, 0.5642857142857143, 'TotalCharges <= 750.775\ngini = 0.302\nsamples = 69\nvalue = [13, 56]'),
#  Text(0.35053989992099027, 0.55, 'TotalCharges <= 741.625\ngini = 0.306\nsamples = 68\nvalue = [13, 55]'),
#  Text(0.3494864366605215, 0.5357142857142857, 'TotalCharges <= 736.4\ngini = 0.309\nsamples = 67\nvalue = [13, 54]'),
#  Text(0.3484329734000527, 0.5214285714285715, 'tenure <= 8.5\ngini = 0.313\nsamples = 66\nvalue = [13, 53]'),
#  Text(0.3473795101395839, 0.5071428571428571, 'TotalCharges <= 715.625\ngini = 0.316\nsamples = 65\nvalue = [13, 52]'),
#  Text(0.3463260468791151, 0.4928571428571429, 'TotalCharges <= 685.15\ngini = 0.32\nsamples = 64\nvalue = [13, 51]'),
#  Text(0.3452725836186463, 0.4785714285714286, 'SeniorCitizen <= 0.5\ngini = 0.324\nsamples = 63\nvalue = [12, 51]'),
#  Text(0.34421912035817753, 0.4642857142857143, 'MonthlyCharges <= 94.975\ngini = 0.268\nsamples = 43\nvalue = [6, 37]'),
#  Text(0.34316565709770874, 0.45, 'MonthlyCharges <= 94.625\ngini = 0.24\nsamples = 42\nvalue = [6, 36]'),
#  Text(0.34211219383723995, 0.4357142857142857, 'TotalCharges <= 652.3\ngini = 0.245\nsamples = 41\nvalue = [6, 35]'),
#  Text(0.3410587305767711, 0.42142857142857143, 'TotalCharges <= 633.725\ngini = 0.25\nsamples = 40\nvalue = [6, 34]'),
#  Text(0.3400052673163023, 0.40714285714285714, 'MonthlyCharges <= 94.15\ngini = 0.255\nsamples = 39\nvalue = [6, 33]'),
#  Text(0.3389518040558335, 0.39285714285714285, 'MonthlyCharges <= 93.725\ngini = 0.26\nsamples = 38\nvalue = [6, 32]'),
#  Text(0.33789834079536474, 0.37857142857142856, 'MonthlyCharges <= 93.525\ngini = 0.266\nsamples = 37\nvalue = [6, 31]'),
#  Text(0.33684487753489595, 0.36428571428571427, 'MonthlyCharges <= 93.0\ngini = 0.272\nsamples = 36\nvalue = [6, 30]'),
#  Text(0.33579141427442716, 0.35, 'TotalCharges <= 617.2\ngini = 0.278\nsamples = 35\nvalue = [6, 29]'),
#  Text(0.33473795101395837, 0.3357142857142857, 'MonthlyCharges <= 92.25\ngini = 0.284\nsamples = 34\nvalue = [6, 28]'),
#  Text(0.3336844877534896, 0.32142857142857145, 'MonthlyCharges <= 91.125\ngini = 0.291\nsamples = 33\nvalue = [6, 27]'),
#  Text(0.331577561232552, 0.30714285714285716, 'MonthlyCharges <= 90.95\ngini = 0.271\nsamples = 30\nvalue = [4, 26]'),
#  Text(0.3305240979720832, 0.29285714285714287, 'MonthlyCharges <= 90.625\ngini = 0.231\nsamples = 29\nvalue = [4, 25]'),
#  Text(0.3294706347116144, 0.2785714285714286, 'MonthlyCharges <= 90.425\ngini = 0.238\nsamples = 28\nvalue = [4, 24]'),
#  Text(0.32841717145114563, 0.2642857142857143, 'tenure <= 6.5\ngini = 0.245\nsamples = 27\nvalue = [4, 23]'),
#  Text(0.32736370819067684, 0.25, 'TotalCharges <= 539.925\ngini = 0.252\nsamples = 26\nvalue = [4, 22]'),
#  Text(0.32631024493020805, 0.2357142857142857, 'TotalCharges <= 522.925\ngini = 0.26\nsamples = 25\nvalue = [4, 21]'),
#  Text(0.32525678166973926, 0.22142857142857142, 'tenure <= 5.5\ngini = 0.269\nsamples = 24\nvalue = [4, 20]'),
#  Text(0.3231498551488017, 0.20714285714285716, 'TotalCharges <= 443.8\ngini = 0.236\nsamples = 21\nvalue = [3, 18]'),
#  Text(0.3220963918883329, 0.19285714285714287, 'TotalCharges <= 425.025\ngini = 0.245\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.3210429286278641, 0.17857142857142858, 'TotalCharges <= 422.3\ngini = 0.255\nsamples = 19\nvalue = [3, 16]'),
#  Text(0.3199894653673953, 0.16428571428571428, 'TotalCharges <= 395.55\ngini = 0.266\nsamples = 18\nvalue = [3, 15]'),
#  Text(0.3189360021069265, 0.15, 'TotalCharges <= 369.375\ngini = 0.278\nsamples = 17\nvalue = [2, 15]'),
#  Text(0.31788253884645773, 0.1357142857142857, 'TotalCharges <= 362.375\ngini = 0.208\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.31682907558598894, 0.12142857142857143, 'TotalCharges <= 355.925\ngini = 0.219\nsamples = 15\nvalue = [2, 13]'),
#  Text(0.31577561232552015, 0.10714285714285714, 'MonthlyCharges <= 89.925\ngini = 0.231\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.31472214906505136, 0.09285714285714286, 'MonthlyCharges <= 89.2\ngini = 0.133\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.31366868580458257, 0.07857142857142857, 'TotalCharges <= 347.05\ngini = 0.142\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.3126152225441138, 0.06428571428571428, 'TotalCharges <= 330.275\ngini = 0.153\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.311561759283645, 0.05, 'tenure <= 2.5\ngini = 0.165\nsamples = 10\nvalue = [1, 9]'),
#  ...]

# %%
# export_text 를 통해 문자( text )로 트리를 시각화 합니다.
# 너무 길어 한눈에 보기가 어려울 경우, max_depth 를 설정하면 특정 깊이까지만 보입니다.
from sklearn.tree import export_text

# 여기에 구현해 주세요.
plot_tree(model, feature_names=feature_names, filled=True, fontsize=10)
# Out:
# [Text(0.38292630798163024, 0.9928571428571429, 'tenure <= 16.5\ngini = 0.389\nsamples = 5634\nvalue = [4146, 1488]'),
#  Text(0.1411455589939426, 0.9785714285714285, 'MonthlyCharges <= 69.225\ngini = 0.495\nsamples = 2048\nvalue = [1122, 926]'),
#  Text(0.06763563339478536, 0.9642857142857143, 'tenure <= 3.5\ngini = 0.418\nsamples = 1142\nvalue = [805, 337]'),
#  Text(0.04065709770871741, 0.95, 'MonthlyCharges <= 20.875\ngini = 0.489\nsamples = 502\nvalue = [288, 214]'),
#  Text(0.021595996839610217, 0.9357142857142857, 'TotalCharges <= 20.275\ngini = 0.387\nsamples = 187\nvalue = [138, 49]'),
#  Text(0.014748485646563076, 0.9214285714285714, 'TotalCharges <= 19.275\ngini = 0.469\nsamples = 96\nvalue = [60, 36]'),
#  Text(0.012641559125625495, 0.9071428571428571, 'gender_encode <= 0.5\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.011588095865156703, 0.8928571428571429, 'TotalCharges <= 19.05\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.010534632604687911, 0.8785714285714286, 'gini = 0.5\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.012641559125625495, 0.8785714285714286, 'gini = 0.0\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.013695022386094284, 0.8928571428571429, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.01685541216750066, 0.9071428571428571, 'TotalCharges <= 20.225\ngini = 0.489\nsamples = 82\nvalue = [47, 35]'),
#  Text(0.015801948907031866, 0.8928571428571429, 'SeniorCitizen <= 0.5\ngini = 0.491\nsamples = 77\nvalue = [44, 33]'),
#  Text(0.014748485646563076, 0.8785714285714286, 'MonthlyCharges <= 20.075\ngini = 0.49\nsamples = 75\nvalue = [44, 31]'),
#  Text(0.012641559125625495, 0.8642857142857143, 'MonthlyCharges <= 20.025\ngini = 0.458\nsamples = 58\nvalue = [37, 21]'),
#  Text(0.011588095865156703, 0.85, 'MonthlyCharges <= 19.925\ngini = 0.465\nsamples = 53\nvalue = [33, 20]'),
#  Text(0.010534632604687911, 0.8357142857142857, 'Partner_encode <= 0.5\ngini = 0.473\nsamples = 48\nvalue = [30, 18]'),
#  Text(0.00948116934421912, 0.8214285714285714, 'Dependents_encode <= 0.5\ngini = 0.48\nsamples = 41\nvalue = [25, 16]'),
#  Text(0.00842770608375033, 0.8071428571428572, 'TotalCharges <= 19.875\ngini = 0.476\nsamples = 38\nvalue = [24, 14]'),
nsamples = 3\nvalue = [1, 2]'),
#  Text(0.028443508032657362, 0.85, 'gini = 0.444\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.030550434553594942, 0.85, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03160389781406373, 0.8642857142857143, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03265736107453253, 0.8785714285714286, 'gini = nan\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0358177508559389, 0.8928571428571429, 'TotalCharges <= 36.15\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.03476428759547011, 0.8785714285714286, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.03687121411640769, 0.8785714285714286, 'TotalCharges <= 39.275\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.0358177508559389, 0.8642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03792467737687648, 0.8642857142857143, 'MonthlyCharges <= 20.625\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.03687121411640769, 0.85, 'TotalCharges <= 54.275\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.0358177508559389, 0.8357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03792467737687648, 0.8357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.038978140637345275, 0.85, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.0597181985778246, 0.9357142857142857, 'TotalCharges <= 169.975\ngini = 0.499\nsamples = 315\nvalue = [150, 165]'),
#  Text(0.05148801685541217, 0.9214285714285714, 'PaperlessBilling_encode <= 0.5\ngini = 0.497\nsamples = 301\nvalue = [138, 163]'),
#  Text(0.04424545693968923, 0.9071428571428571, 'MonthlyCharges <= 61.6\ngini = 0.496\nsamples = 141\nvalue = [77, 64]'),
#  Text(0.043191993679220435, 0.8928571428571429, 'TotalCharges <= 152.8\ngini = 0.495\nsamples = 136\nvalue = [77, 59]'),
#  Text(0.042138530418751645, 0.8785714285714286, 'TotalCharges <= 89.775\ngini = 0.491\nsamples = 132\nvalue = [75, 57]'),
#  Text(0.041085067158282855, 0.8642857142857143, 'gini = 0.496\nsamples = 106\nvalue = [56, 50]'),
#  Text(0.043191993679220435, 0.8642857142857143, 'gender_encode <= 0.5\ngini = 0.434\nsamples = 26\nvalue = [19, 7]'),
#  Text(0.042138530418751645, 0.85, 'PhoneService_encode <= 0.5\ngini = 0.465\nsamples = 15\nvalue = [8, 7]'),
#  Text(0.040031603897814065, 0.8357142857142857, 'Partner_encode <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.038978140637345275, 0.8214285714285714, 'gini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.041085067158282855, 0.8214285714285714, 'gini = nan\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04424545693968923, 0.8357142857142857, 'Partner_encode <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.043191993679220435, 0.8214285714285714, 'tenure <= 2.5\ngini = 0.494\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.042138530418751645, 0.8071428571428572, 'SeniorCitizen <= 0.5\ngini = 0.408\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.041085067158282855, 0.7928571428571428, 'gini = 0.32\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.043191993679220435, 0.7928571428571428, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04424545693968923, 0.8071428571428572, 'gini = nan\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04529892020015802, 0.8214285714285714, 'gini = nan\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04424545693968923, 0.85, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.04424545693968923, 0.8785714285714286, 'gini = nan\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.04529892020015802, 0.8928571428571429, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.05873057677113511, 0.9071428571428571, 'PhoneService_encode <= 0.5\ngini = 0.472\nsamples = 160\nvalue = [61, 99]'),
#  Text(0.05372662628390835, 0.8928571428571429, 'tenure <= 2.5\ngini = 0.289\nsamples = 40\nvalue = [7, 33]'),
#  Text(0.05161969976297077, 0.8785714285714286, 'Partner_encode <= 0.5\ngini = 0.278\nsamples = 32\nvalue = [4, 28]'),
#  Text(0.05056623650250198, 0.8642857142857143, 'MonthlyCharges <= 40.025\ngini = 0.124\nsamples = 26\nvalue = [2, 24]'),
#  Text(0.04951277324203318, 0.85, 'Dependents_encode <= 0.5\ngini = 0.142\nsamples = 22\nvalue = [2, 20]'),
#  Text(0.04845930998156439, 0.8357142857142857, 'TotalCharges <= 51.925\ngini = 0.165\nsamples = 21\nvalue = [2, 19]'),
#  Text(0.0474058467210956, 0.8214285714285714, 'TotalCharges <= 35.65\ngini = 0.172\nsamples = 17\nvalue = [2, 15]'),
#  Text(0.04635238346062681, 0.8071428571428572, 'gender_encode <= 0.5\ngini = 0.208\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.04529892020015802, 0.7928571428571428, 'gini = -1.92\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.0474058467210956, 0.7928571428571428, 'SeniorCitizen <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.04635238346062681, 0.7785714285714286, 'TotalCharges <= 24.8\ngini = 0.219\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.04529892020015802, 0.7642857142857142, 'gini = -4.0\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0474058467210956, 0.7642857142857142, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.04845930998156439, 0.7785714285714286, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04845930998156439, 0.8071428571428572, 'gini = nan\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.04951277324203318, 0.8214285714285714, 'gini = nan\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.05056623650250198, 0.8357142857142857, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05161969976297077, 0.85, 'gini = nan\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.05267316302343956, 0.8642857142857143, 'gini = 0.0\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.05583355280484593, 0.8785714285714286, 'SeniorCitizen <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.05478008954437714, 0.8642857142857143, 'MonthlyCharges <= 30.375\ngini = 0.469\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.05372662628390835, 0.85, 'gini = -12.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05583355280484593, 0.85, 'gini = 0.0\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.056887016065314724, 0.8642857142857143, 'gini = nan\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06373452725836186, 0.8928571428571429, 'MonthlyCharges <= 68.125\ngini = 0.495\nsamples = 120\nvalue = [54, 66]'),
#  Text(0.06268106399789307, 0.8785714285714286, 'Partner_encode <= 0.5\ngini = 0.495\nsamples = 116\nvalue = [54, 62]'),
#  Text(0.058993942586252304, 0.8642857142857143, 'MonthlyCharges <= 60.675\ngini = 0.495\nsamples = 98\nvalue = [44, 54]'),
#  Text(0.057940479325783514, 0.85, 'Dependents_encode <= 0.5\ngini = 0.495\nsamples = 94\nvalue = [42, 52]'),
#  Text(0.05583355280484593, 0.8357142857142857, 'TotalCharges <= 140.95\ngini = 0.494\nsamples = 86\nvalue = [36, 50]'),
#  Text(0.05478008954437714, 0.8214285714285714, 'tenure <= 2.5\ngini = 0.487\nsamples = 82\nvalue = [33, 49]'),
#  Text(0.05372662628390835, 0.8071428571428572, 'TotalCharges <= 111.675\ngini = 0.481\nsamples = 80\nvalue = [32, 48]'),
#  Text(0.05267316302343956, 0.7928571428571428, 'TotalCharges <= 104.175\ngini = 0.48\nsamples = 76\nvalue = [30, 46]'),
#  Text(0.05161969976297077, 0.7785714285714286, 'MonthlyCharges <= 55.575\ngini = 0.478\nsamples = 72\nvalue = [28, 44]'),
#  Text(0.05056623650250198, 0.7642857142857142, 'TotalCharges <= 93.225\ngini = 0.475\nsamples = 68\nvalue = [28, 40]'),
#  Text(0.04951277324203318, 0.75, 'SeniorCitizen <= 0.5\ngini = 0.484\nsamples = 64\nvalue = [28, 36]'),
#  Text(0.04845930998156439, 0.7357142857142858, 'tenure <= 1.5\ngini = 0.492\nsamples = 61\nvalue = [27, 34]'),
#  Text(0.04635238346062681, 0.7214285714285714, 'MonthlyCharges <= 54.825\ngini = 0.49\nsamples = 54\nvalue = [23, 31]'),
#  Text(0.04529892020015802, 0.7071428571428572, 'MonthlyCharges <= 52.85\ngini = 0.489\nsamples = 50\nvalue = [21, 29]'),
#  Text(0.04424545693968923, 0.6928571428571428, 'TotalCharges <= 50.6\ngini = 0.487\nsamples = 46\nvalue = [21, 25]'),
#  Text(0.043191993679220435, 0.6785714285714286, 'TotalCharges <= 50.125\ngini = 0.496\nsamples = 42\nvalue = [20, 22]'),
 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.09461416908085331, 0.95, 'MonthlyCharges <= 20.925\ngini = 0.311\nsamples = 640\nvalue = [517, 123]'),
#  Text(0.07374242823281538, 0.9357142857142857, 'MonthlyCharges <= 20.375\ngini = 0.164\nsamples = 233\nvalue = [212, 21]'),
#  Text(0.07268896497234659, 0.9214285714285714, 'gender_encode <= 0.5\ngini = 0.197\nsamples = 187\nvalue = [166, 21]'),
#  Text(0.0716355017118778, 0.9071428571428571, 'TotalCharges <= 80.2\ngini = 0.273\nsamples = 95\nvalue = [80, 15]'),
#  Text(0.07058203845140901, 0.8928571428571429, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.07268896497234659, 0.8928571428571429, 'TotalCharges <= 107.425\ngini = 0.243\nsamples = 92\nvalue = [79, 13]'),
#  Text(0.0716355017118778, 0.8785714285714286, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.07374242823281538, 0.8785714285714286, 'TotalCharges <= 108.625\ngini = 0.272\nsamples = 80\nvalue = [67, 13]'),
#  Text(0.07268896497234659, 0.8642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07479589149328417, 0.8642857142857143, 'TotalCharges <= 167.875\ngini = 0.258\nsamples = 79\nvalue = [67, 12]'),
#  Text(0.07058203845140901, 0.85, 'TotalCharges <= 144.975\ngini = 0.386\nsamples = 23\nvalue = [17, 6]'),
#  Text(0.06847511193047143, 0.8357142857142857, 'TotalCharges <= 133.575\ngini = 0.298\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.06742164867000264, 0.8214285714285714, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.06952857519094022, 0.8214285714285714, 'TotalCharges <= 139.275\ngini = 0.5\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.06847511193047143, 0.8071428571428572, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07058203845140901, 0.8071428571428572, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.07268896497234659, 0.8357142857142857, 'MonthlyCharges <= 19.35\ngini = 0.444\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.0716355017118778, 0.8214285714285714, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.07374242823281538, 0.8214285714285714, 'TotalCharges <= 158.15\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.07268896497234659, 0.8071428571428572, 'TotalCharges <= 146.45\ngini = 0.469\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.0716355017118778, 0.7928571428571428, 'gini = -1.5\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07374242823281538, 0.7928571428571428, 'gini = 0.0\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.07479589149328417, 0.8071428571428572, 'gini = nan\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.07900974453515934, 0.85, 'MonthlyCharges <= 19.275\ngini = 0.191\nsamples = 56\nvalue = [50, 6]'),
#  Text(0.07690281801422176, 0.8357142857142857, 'Dependents_encode <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.07584935475375296, 0.8214285714285714, 'gini = -4.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07795628127469055, 0.8214285714285714, 'gini = 0.0\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.08111667105609692, 0.8357142857142857, 'TotalCharges <= 221.075\ngini = 0.142\nsamples = 52\nvalue = [48, 4]'),
#  Text(0.08006320779562813, 0.8214285714285714, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.08217013431656571, 0.8214285714285714, 'TotalCharges <= 222.475\ngini = 0.213\nsamples = 33\nvalue = [29, 4]'),
#  Text(0.08111667105609692, 0.8071428571428572, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0832235975770345, 0.8071428571428572, 'MonthlyCharges <= 19.85\ngini = 0.17\nsamples = 32\nvalue = [29, 3]'),
#  Text(0.08217013431656571, 0.7928571428571428, 'gini = 0.236\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.08427706083750329, 0.7928571428571428, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.07374242823281538, 0.9071428571428571, 'gini = 0.106\nsamples = 92\nvalue = [86, 6]'),
#  Text(0.07479589149328417, 0.9214285714285714, 'gini = 0.0\nsamples = 46\nvalue = [46, 0]'),
#  Text(0.11548590992889123, 0.9357142857142857, 'TotalCharges <= 310.9\ngini = 0.376\nsamples = 407\nvalue = [305, 102]'),
#  Text(0.095206742164867, 0.9214285714285714, 'MonthlyCharges <= 54.45\ngini = 0.455\nsamples = 154\nvalue = [100, 54]'),
#  Text(0.09415327890439822, 0.9071428571428571, 'Dependents_encode <= 0.5\ngini = 0.473\nsamples = 135\nvalue = [83, 52]'),
#  Text(0.09007110877008165, 0.8928571428571429, 'MonthlyCharges <= 30.175\ngini = 0.495\nsamples = 93\nvalue = [51, 42]'),
#  Text(0.08796418224914405, 0.8785714285714286, 'TotalCharges <= 98.125\ngini = 0.438\nsamples = 37\nvalue = [25, 12]'),
#  Text(0.08691071898867526, 0.8642857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.
nsamples = 19\nvalue = [17, 2]'),
#  Text(0.13576507769291546, 0.9214285714285714, 'TotalCharges <= 890.825\ngini = 0.307\nsamples = 253\nvalue = [205, 48]'),
#  Text(0.12615222544113774, 0.9071428571428571, 'MonthlyCharges <= 58.675\ngini = 0.285\nsamples = 235\nvalue = [196, 39]'),
#  Text(0.11640769028180142, 0.8928571428571429, 'MonthlyCharges <= 40.6\ngini = 0.309\nsamples = 170\nvalue = [137, 33]'),
#  Text(0.11061364234922307, 0.8785714285714286, 'PaperlessBilling_encode <= 0.5\ngini = 0.136\nsamples = 41\nvalue = [38, 3]'),
#  Text(0.10956017908875428, 0.8642857142857143, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.11166710560969186, 0.8642857142857143, 'gender_encode <= 0.5\ngini = 0.236\nsamples = 22\nvalue = [19, 3]'),
#  Text(0.11061364234922307, 0.85, 'TotalCharges <= 330.3\ngini = 0.305\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.10956017908875428, 0.8357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11166710560969186, 0.8357142857142857, 'MonthlyCharges <= 31.35\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.11061364234922307, 0.8214285714285714, 'Dependents_encode <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.10956017908875428, 0.8071428571428572, 'gini = 0.48\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.11166710560969186, 0.8071428571428572, 'gini = nan\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11272056887016066, 0.8214285714285714, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.11272056887016066, 0.85, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.12220173821437977, 0.8785714285714286, 'PhoneService_encode <= 0.5\ngini = 0.357\nsamples = 129\nvalue = [99, 30]'),
#  Text(0.1190413484329734, 0.8642857142857143, 'tenure <= 13.5\ngini = 0.495\nsamples = 20\nvalue = [11, 9]'),
#  Text(0.11798788517250461, 0.85, 'tenure <= 12.5\ngini = 0.499\nsamples = 16\nvalue = [9, 7]'),
#  Text(0.11693442191203582, 0.8357142857142857, 'tenure <= 9.5\ngini = 0.48\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.11482749539109824, 0.8214285714285714, 'PaperlessBilling_encode <= 0.5\ngini = 0.42\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.11377403213062945, 0.8071428571428572, 'TotalCharges <= 344.175\ngini = 0.49\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.11272056887016066, 0.7928571428571428, 'gini = -4.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11482749539109824, 0.7928571428571428, 'gini = 0.0\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.11588095865156703, 0.8071428571428572, 'gini = nan\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1190413484329734, 0.8214285714285714, 'gender_encode <= 0.5\ngini = 0.5\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.11798788517250461, 0.8071428571428572, 'gini = 0.32\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.12009481169344219, 0.8071428571428572, 'gini = nan\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1190413484329734, 0.8357142857142857, 'gini = 0.0\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.12009481169344219, 0.85, 'gini = 0.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.12536212799578614, 0.8642857142857143, 'TotalCharges <= 534.65\ngini = 0.311\nsamples = 109\nvalue = [88, 21]'),
#  Text(0.12430866473531736, 0.85, 'gini = 0.367\nsamples = 59\nvalue = [44, 15]'),
#  Text(0.12641559125625493, 0.85, 'TotalCharges <= 675.1\ngini = 0.223\nsamples = 50\nvalue = [44, 6]'),
#  Text(0.12430866473531736, 0.8357142857142857, 'tenure <= 11.5\ngini = 0.128\nsamples = 26\nvalue = [25, 1]'),
#  Text(0.12325520147484856, 0.8214285714285714, 'MonthlyCharges <= 53.775\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.12220173821437977, 0.8071428571428572, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.12430866473531736, 0.8071428571428572, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.12536212799578614, 0.8214285714285714, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.1285225177771925, 0.8357142857142857, 'TotalCharges <= 698.7\ngini = 0.308\nsamples = 24\nvalue = [19, 5]'),
#  Text(0.12746905451672372, 0.8214285714285714, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.12957598103766133, 0.8214285714285714, 'Partner_encode <= 0.5\ngini = 0.245\nsamples = 21\nvalue = [18, 3]'),
#  Text(0.12746905451672372, 0.8071428571428572, 'MonthlyCharges <= 54.0\ngini = 0.198\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.12641559125625493, 0.7928571428571428, 'MonthlyCharges <= 49.775\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.12536212799578614, 0.7785714285714286, 'gini = 0.444\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.12746905451672372, 0.7785714285714286, 'gender_encode <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.12641559125625493, 0.7642857142857142, 'gini = 0.5\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1285225177771925, 0.7642857142857142, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1285225177771925, 0.7928571428571428, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0
nsamples = 7\nvalue = [1, 6]'),
#  Text(0.14748485646563075, 0.8071428571428572, 'TotalCharges <= 71.0\ngini = 0.245\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.14643139320516196, 0.7928571428571428, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.14853831972609954, 0.7928571428571428, 'gini = 0.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14959178298656833, 0.8071428571428572, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15064524624703712, 0.8214285714285714, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15064524624703712, 0.85, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1516987095075059, 0.8642857142857143, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1548590992889123, 0.8785714285714286, 'TotalCharges <= 75.0\ngini = 0.375\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.15380563602844352, 0.8642857142857143, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.1559125625493811, 0.8642857142857143, 'gini = 0.0\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1635501711877798, 0.8928571428571429, 'MonthlyCharges <= 72.825\ngini = 0.348\nsamples = 58\nvalue = [13, 45]'),
#  Text(0.16065314722149066, 0.8785714285714286, 'gender_encode <= 0.5\ngini = 0.451\nsamples = 31\nvalue = [11, 20]'),
#  Text(0.15801948907031868, 0.8642857142857143, 'MonthlyCharges <= 71.2\ngini = 0.401\nsamples = 17\nvalue = [5, 12]'),
#  Text(0.1569660258098499, 0.85, 'TotalCharges <= 71.075\ngini = 0.375\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.1559125625493811, 0.8357142857142857, 'Dependents_encode <= 0.5\ngini = 0.32\nsamples = 14\nvalue = [3, 11]'),
#  Text(0.1548590992889123, 0.8214285714285714, 'TotalCharges <= 70.65\ngini = 0.337\nsamples = 13\nvalue = [3, 10]'),
#  Text(0.15380563602844352, 0.8071428571428572, 'Partner_encode <= 0.5\ngini = 0.278\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.1527521727679747, 0.7928571428571428, 'gini = 0.298\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.1548590992889123, 0.7928571428571428, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1559125625493811, 0.8071428571428572, 'gini = 0.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1569660258098499, 0.8214285714285714, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15801948907031868, 0.8357142857142857, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15907295233078747, 0.85, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16328680537266263, 0.8642857142857143, 'SeniorCitizen <= 0.5\ngini = 0.497\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.16223334211219384, 0.85, 'MonthlyCharges <= 71.075\ngini = 0.497\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.16117987885172505, 0.8357142857142857, 'Dependents_encode <= 0.5\ngini = 0.496\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.15907295233078747, 0.8214285714285714, 'MonthlyCharges <= 70.2\ngini = 0.49\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.15801948907031868, 0.8071428571428572, 'TotalCharges <= 69.975\ngini = 0.48\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.1569660258098499, 0.7928571428571428, 'gini = 0.375\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.15907295233078747, 0.7928571428571428, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16012641559125626, 0.8071428571428572, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16328680537266263, 0.8214285714285714, 'MonthlyCharges <= 69.975\ngini = 0.444\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.16223334211219384, 0.8071428571428572, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16434026863313142, 0.8071428571428572, 'Partner_encode <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.16328680537266263, 0.7928571428571428, 'gini = 0.444\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1653937318936002, 0.7928571428571428, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16328680537266263, 0.8357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.16434026863313142, 0.85, 'gini = 0.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.166447195154069, 0.8785714285714286, 'TotalCharges <= 75.4\ngini = 0.142\nsamples = 27\nvalue = [2, 25]'),
#  Text(0.1653937318936002, 0.8642857142857143, 'gini = 0.137\nsamples = 26\nvalue = [2, 24]'),
#  Text(0.1675006584145378, 0.8642857142857143, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16025809849881487, 0.9071428571428571, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1796154859099289, 0.9357142857142857, 'tenure <= 1.5\ngini = 0.198\nsamples = 82\nvalue = [9, 73]'),
#  Text(0.1785620226494601, 0.9214285714285714, 'TotalCharges <= 101.625\ngini = 0.195\nsamples = 81\nvalue = [9, 72]'),
#  Text(0.17750855938899132, 0.9071428571428571, 'Dependents_encode <= 0.5\ngini = 0.198\nsamples = 80\nvalue = [9, 71]'),
#  Text(0.17487490123781932, 0.8928571428571429, 'TotalCharges <= 100.525\ngini = 0.157\nsamples = 69\nvalue = [6, 63]'),
#  Text(0.17382143797735053, 0.8785714285714286, 'TotalCharges <= 98.05\ngini = 0.159\nsamples = 68\nvalue = [6, 62]'),
#  Text(0.17276797471688174, 0.8642857142857143, 'TotalCharges <= 95.75\ngini = 0.161\nsamples = 67\nvalue = [6, 61]'),
#  Text(0.17171451145641295, 0.85, 'MonthlyCharges <= 95.625\ngini = 0.163\nsamples = 66\nvalue = [5, 61]'),
#  Text(0.17066104819594416, 0.8357142857142857, 'TotalCharges <= 95.35\ngini = 0.14\nsamples = 65\nvalue = [5, 60]'),
#  Text(0.16960758493547537, 0.8214285714285714, 'TotalCharges <= 95.05\ngini = 0.142\nsamples = 64\nvalue = [5, 59]'),
#  Text(0.16855412167500658, 0.8071428571428572, 'MonthlyCharges <= 94.8\ngini = 0.144\nsamples = 63\nvalue = [5, 58]'),
#  Text(0.1675006584145378, 0.7928571428571428, 'TotalCharges <= 94.3\ngini = 0.146\nsamples = 62\nvalue = [5, 57]'),
#  Text(0.166447195154069, 0.7785714285714286, 'TotalCharges <= 93.925\ngini = 0.148\nsamples = 61\nvalue = [5, 56]'),
#  Text(0.1653937318936002, 0.7642857142857142, 'TotalCharges <= 93.7\ngini = 0.15\nsamples = 60\nvalue = [5, 55]'),
#  Text(0.16434026863313142, 0.75, 'MonthlyCharges <= 92.625\ngini = 0.153\nsamples = 59\nvalue = [5, 54]'),
#  Text(0.16328680537266263, 0.7357142857142858, 'MonthlyCharges <= 91.5\ngini = 0.155\nsamples = 58\nvalue = [5, 53]'),
#  Text(0.16223334211219384, 0.7214285714285714, 'MonthlyCharges <= 91.075\ngini = 0.158\nsamples = 57\nvalue = [5, 52]'),
#  Text(0.16117987885172505, 0.7071428571428572, 'MonthlyCharges <= 90.8\ngini = 0.16\nsamples = 56\nvalue = [5, 51]'),
#  Text(0.16012641559125626, 0.6928571428571428, 'MonthlyCharges <= 90.675\ngini = 0.163\nsamples = 55\nvalue = [5, 50]'),
#  Text(0.15907295233078747, 0.6785714285714286, 'TotalCharges <= 90.575\ngini = 0.165\nsamples = 54\nvalue = [5, 49]'),
#  Text(0.15801948907031868, 0.6642857142857143, 'PaperlessBilling_encode <= 0.5\ngini = 0.168\nsamples = 53\nvalue = [5, 48]'),
#  Text(0.1569660258098499, 0.65, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.15907295233078747, 0.65, 'MonthlyCharges <= 90.225\ngini = 0.219\nsamples = 40\nvalue = [5, 35]'),
#  Text(0.15801948907031868, 0.6357142857142857, 'TotalCharges <= 89.725\ngini = 0.219\nsamples = 39\nvalue = [5, 34]'),
#  Text(0.1569660258098499, 0.6214285714285714, 'TotalCharges <= 89.4\ngini = 0.224\nsamples = 38\nvalue = [5, 33]'),
#  Text(0.1559125625493811, 0.6071428571428571, 'TotalCharges <= 89.175\ngini = 0.229\nsamples = 37\nvalue = [5, 32]'),
#  Text(0.1548590992889123, 0.5928571428571429, 'TotalCharges <= 88.95\ngini = 0.234\nsamples = 36\nvalue = [4, 32]'),
#  Text(0.15380563602844352, 0.5785714285714286, 'TotalCharges <= 88.575\ngini = 0.198\nsamples = 35\nvalue = [4, 31]'),
ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.356860679483803, 0.7785714285714286, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3589676060047406, 0.7785714285714286, 'TotalCharges <= 1092.15\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.3579141427442718, 0.7642857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3600210692652094, 0.7642857142857142, 'gender_encode <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.3579141427442718, 0.75, 'TotalCharges <= 1194.15\ngini = 0.444\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.356860679483803, 0.7357142857142858, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3589676060047406, 0.7357142857142858, 'TotalCharges <= 1305.525\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3579141427442718, 0.7214285714285714, 'TotalCharges <= 1280.475\ngini = 0.444\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.356860679483803, 0.7071428571428572, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3589676060047406, 0.7071428571428572, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3600210692652094, 0.7214285714285714, 'gini = nan\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36212799578614696, 0.75, 'MonthlyCharges <= 80.375\ngini = 0.5\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.36107453252567817, 0.7357142857142858, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36318145904661575, 0.7357142857142858, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3552804845930998, 0.8357142857142857, 'gini = 0.0\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.39643139320516196, 0.9071428571428571, 'Dependents_encode <= 0.5\ngini = 0.373\nsamples = 262\nvalue = [65, 197]'),
#  Text(0.3885962602054253, 0.8928571428571429, 'MonthlyCharges <= 95.95\ngini = 0.346\nsamples = 228\nvalue = [51, 177]'),
#  Text(0.37713984724782723, 0.8785714285714286, 'TotalCharges <= 956.675\ngini = 0.39\nsamples = 157\nvalue = [42, 115]'),
#  Text(0.37476955491177244, 0.8642857142857143, 'tenure <= 10.5\ngini = 0.332\nsamples = 113\nvalue = [24, 89]'),
#  Text(0.37371609165130365, 0.85, 'TotalCharges <= 943.775\ngini = 0.335\nsamples = 112\nvalue = [24, 88]'),
#  Text(0.37266262839083486, 0.8357142857142857, 'TotalCharges <= 924.2\ngini = 0.337\nsamples = 111\nvalue = [24, 87]'),
#  Text(0.37160916513036607, 0.8214285714285714, 'MonthlyCharges <= 95.75\ngini = 0.339\nsamples = 110\nvalue = [24, 86]'),
#  Text(0.3705557018698973, 0.8071428571428572, 'TotalCharges <= 906.325\ngini = 0.341\nsamples = 109\nvalue = [23, 86]'),
#  Text(0.3695022386094285, 0.7928571428571428, 'TotalCharges <= 894.475\ngini = 0.333\nsamples = 108\nvalue = [23, 85]'),
#  Text(0.3684487753489597, 0.7785714285714286, 'TotalCharges <= 890.25\ngini = 0.335\nsamples = 107\nvalue = [23, 84]'),
#  Text(0.3673953120884909, 0.7642857142857142, 'MonthlyCharges <= 95.55\ngini = 0.337\nsamples = 106\nvalue = [23, 83]'),
#  Text(0.3663418488280221, 0.75, 'TotalCharges <= 877.5\ngini = 0.34\nsamples = 105\nvalue = [23, 82]'),
#  Text(0.36528838556755333, 0.7357142857142858, 'TotalCharges <= 864.1\ngini = 0.342\nsamples = 104\nvalue = [23, 81]'),
#  Text(0.36423492230708454, 0.7214285714285714, 'Partner_encode <= 0.5\ngini = 0.344\nsamples = 103\nvalue = [22, 81]'),
#  Text(0.36212799578614696, 0.7071428571428572, 'MonthlyCharges <= 95.475\ngini = 0.299\nsamples = 81\nvalue = [15, 66]'),
#  Text(0.36107453252567817, 0.6928571428571428, 'TotalCharges <= 848.6\ngini = 0.302\nsamples = 80\nvalue = [15, 65]'),
#  Text(0.3600210692652094, 0.6785714285714286, 'TotalCharges <= 833.075\ngini = 0.305\nsamples = 79\nvalue = [15, 64]'),
#  Text(0.3589676060047406, 0.6642857142857143, 'TotalCharges <= 781.125\ngini = 0.308\nsamples = 78\nvalue = [15, 63]'),
#  Text(0.3579141427442718, 0.65, 'MonthlyCharges <= 95.4\ngini = 0.284\nsamples = 75\nvalue = [13, 62]'),
#  Text(0.356860679483803, 0.6357142857142857, 'MonthlyCharges <= 95.25\ngini = 0.287\nsamples = 74\nvalue = [13, 61]'),
#  Text(0.3558072162233342, 0.6214285714285714, 'MonthlyCharges <= 95.125\ngini = 0.29\nsamples = 73\nvalue = [13, 60]'),
#  Text(0.35475375296286543, 0.6071428571428571, 'TotalCharges <= 768.075\ngini = 0.293\nsamples = 72\nvalue = [13, 59]'),
#  Text(0.35370028970239664, 0.5928571428571429, 'TotalCharges <= 762.3\ngini = 0.296\nsamples = 71\nvalue = [13, 58]'),
#  Text(0.35264682644192785, 0.5785714285714286, 'TotalCharges <= 760.35\ngini = 0.299\nsamples = 70\nvalue = [13, 57]'),
#  Text(0.35159336318145906, 0.5642857142857143, 'TotalCharges <= 750.775\ngini = 0.302\nsamples = 69\nvalue = [13, 56]'),
#  Text(0.35053989992099027, 0.55, 'TotalCharges <= 741.625\ngini = 0.306\nsamples = 68\nvalue = [13, 55]'),
#  Text(0.3494864366605215, 0.5357142857142857, 'TotalCharges <= 736.4\ngini = 0.309\nsamples = 67\nvalue = [13, 54]'),
#  Text(0.3484329734000527, 0.5214285714285715, 'tenure <= 8.5\ngini = 0.313\nsamples = 66\nvalue = [13, 53]'),
#  Text(0.3473795101395839, 0.5071428571428571, 'TotalCharges <= 715.625\ngini = 0.316\nsamples = 65\nvalue = [13, 52]'),
#  Text(0.3463260468791151, 0.4928571428571429, 'TotalCharges <= 685.15\ngini = 0.32\nsamples = 64\nvalue = [13, 51]'),
#  Text(0.3452725836186463, 0.4785714285714286, 'SeniorCitizen <= 0.5\ngini = 0.324\nsamples = 63\nvalue = [12, 51]'),
#  Text(0.34421912035817753, 0.4642857142857143, 'MonthlyCharges <= 94.975\ngini = 0.268\nsamples = 43\nvalue = [6, 37]'),
#  Text(0.34316565709770874, 0.45, 'MonthlyCharges <= 94.625\ngini = 0.24\nsamples = 42\nvalue = [6, 36]'),
#  Text(0.34211219383723995, 0.4357142857142857, 'TotalCharges <= 652.3\ngini = 0.245\nsamples = 41\nvalue = [6, 35]'),
#  Text(0.3410587305767711, 0.42142857142857143, 'TotalCharges <= 633.725\ngini = 0.25\nsamples = 40\nvalue = [6, 34]'),
#  Text(0.3400052673163023, 0.40714285714285714, 'MonthlyCharges <= 94.15\ngini = 0.255\nsamples = 39\nvalue = [6, 33]'),
#  Text(0.3389518040558335, 0.39285714285714285, 'MonthlyCharges <= 93.725\ngini = 0.26\nsamples = 38\nvalue = [6, 32]'),
#  Text(0.33789834079536474, 0.37857142857142856, 'MonthlyCharges <= 93.525\ngini = 0.266\nsamples = 37\nvalue = [6, 31]'),
#  Text(0.33684487753489595, 0.36428571428571427, 'MonthlyCharges <= 93.0\ngini = 0.272\nsamples = 36\nvalue = [6, 30]'),
#  Text(0.33579141427442716, 0.35, 'TotalCharges <= 617.2\ngini = 0.278\nsamples = 35\nvalue = [6, 29]'),
#  Text(0.33473795101395837, 0.3357142857142857, 'MonthlyCharges <= 92.25\ngini = 0.284\nsamples = 34\nvalue = [6, 28]'),
#  Text(0.3336844877534896, 0.32142857142857145, 'MonthlyCharges <= 91.125\ngini = 0.291\nsamples = 33\nvalue = [6, 27]'),
#  Text(0.331577561232552, 0.30714285714285716, 'MonthlyCharges <= 90.95\ngini = 0.271\nsamples = 30\nvalue = [4, 26]'),
#  Text(0.3305240979720832, 0.29285714285714287, 'MonthlyCharges <= 90.625\ngini = 0.231\nsamples = 29\nvalue = [4, 25]'),
#  Text(0.3294706347116144, 0.2785714285714286, 'MonthlyCharges <= 90.425\ngini = 0.238\nsamples = 28\nvalue = [4, 24]'),
#  Text(0.32841717145114563, 0.2642857142857143, 'tenure <= 6.5\ngini = 0.245\nsamples = 27\nvalue = [4, 23]'),
#  Text(0.32736370819067684, 0.25, 'TotalCharges <= 539.925\ngini = 0.252\nsamples = 26\nvalue = [4, 22]'),
#  Text(0.32631024493020805, 0.2357142857142857, 'TotalCharges <= 522.925\ngini = 0.26\nsamples = 25\nvalue = [4, 21]'),
#  Text(0.32525678166973926, 0.22142857142857142, 'tenure <= 5.5\ngini = 0.269\nsamples = 24\nvalue = [4, 20]'),
#  Text(0.3231498551488017, 0.20714285714285716, 'TotalCharges <= 443.8\ngini = 0.236\nsamples = 21\nvalue = [3, 18]'),
#  Text(0.3220963918883329, 0.19285714285714287, 'TotalCharges <= 425.025\ngini = 0.245\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.3210429286278641, 0.17857142857142858, 'TotalCharges <= 422.3\ngini = 0.255\nsamples = 19\nvalue = [3, 16]'),
#  Text(0.3199894653673953, 0.16428571428571428, 'TotalCharges <= 395.55\ngini = 0.266\nsamples = 18\nvalue = [3, 15]'),
#  Text(0.3189360021069265, 0.15, 'TotalCharges <= 369.375\ngini = 0.278\nsamples = 17\nvalue = [2, 15]'),
#  Text(0.31788253884645773, 0.1357142857142857, 'TotalCharges <= 362.375\ngini = 0.208\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.31682907558598894, 0.12142857142857143, 'TotalCharges <= 355.925\ngini = 0.219\nsamples = 15\nvalue = [2, 13]'),
#  Text(0.31577561232552015, 0.10714285714285714, 'MonthlyCharges <= 89.925\ngini = 0.231\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.31472214906505136, 0.09285714285714286, 'MonthlyCharges <= 89.2\ngini = 0.133\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.31366868580458257, 0.07857142857142857, 'TotalCharges <= 347.05\ngini = 0.142\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.3126152225441138, 0.06428571428571428, 'TotalCharges <= 330.275\ngini = 0.153\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.311561759283645, 0.05, 'tenure <= 2.5\ngini = 0.165\nsamples = 10\nvalue = [1, 9]'),
#  ...]

# %%
# feature_importances_ 를 통해 모델의 피처 중요도를 추출합니다.

model.feature_importances_
# Out:
# array([       nan,        nan,        nan,        nan,        nan,
#               nan,        nan, 0.00205389,        nan])

# %%
# 피처 중요도를 시각화 합니다.
# 여기에 구현해 주세요. 위 예시 이미지를 참고합니다.

sns.barplot(x=model.feature_importances_,y=feature_names)
# Out:
# <Axes: ylabel='None'>

# %%
# 빈칸을 채워 정확도(accuracy) 를 구해주세요.
# 정답과 같이 예측한 값은 True 로 나오게 됩니다.
# True == 1 이기 때문에 평균값을 내면 정답을 맞춘 비율을 구할 수 있습니다.

from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_predict)
# Out:
# 0.9424920127795527
